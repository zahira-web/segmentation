# %%
pip install tensorflow opencv-python matplotlib
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from glob import glob
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, concatenate
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from tensorflow.keras.utils import Sequence
from glob import glob
import pandas as pd
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator




import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

import cv2
from tqdm import tqdm_notebook, tnrange
from glob import glob
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split
from IPython.display import Image, display

import tensorflow as tf
from skimage.color import rgb2gray
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate
from tensorflow.keras.optimizers.legacy import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/seg/kaggle_3m
# Out:
# /content/drive/MyDrive/seg/kaggle_3m

# %%
import os
import numpy as np
from PIL import Image
from tqdm import tqdm

root_dir = '/content/drive/MyDrive/seg/kaggle_3m'
image_size = (128, 128)

images = []
masks = []

for foldername, subfolders, filenames in os.walk(root_dir):

    for filename in tqdm(filenames, desc=f"Processing {foldername}"):
        if filename.endswith('.tif') and '_mask' not in filename:
            image_path = os.path.join(foldername, filename)

            base_name = filename.replace('.tif', '')
            mask_name = base_name + '_mask.tif'
            mask_path = os.path.join(foldername, mask_name)

            if not os.path.exists(mask_path):
                print(f"❌ no mask for {filename}")
                continue

            try:
                img = Image.open(image_path).convert('L')
                mask = Image.open(mask_path).convert('L')

                img = img.resize(image_size)
                mask = mask.resize(image_size)

                img_array = np.array(img) / 255.0
                mask_array = np.array(mask) / 255.0

                images.append(img_array.reshape(128, 128, 1))
                masks.append(mask_array.reshape(128, 128, 1))
            except Exception as e:
                print(f"⚠️ error in {filename}: {e}")

images = np.array(images)
masks = np.array(masks)

print("✅ Images shape", images.shape)
print("✅ Masks shape", masks.shape)
# Out:
# Processing /content/drive/MyDrive/seg/kaggle_3m: 100%|██████████| 4/4 [00:00<00:00, 20535.15it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/TCGA_CS_6188_20010812: 100%|██████████| 48/48 [00:15<00:00,  3.05it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/TCGA_CS_5396_20010302: 100%|██████████| 48/48 [00:16<00:00,  2.99it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/TCGA_CS_4941_19960909: 100%|██████████| 46/46 [00:15<00:00,  2.91it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/TCGA_CS_4942_19970222: 100%|██████████| 40/40 [00:14<00:00,  2.83it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/TCGA_CS_5397_20010315: 100%|██████████| 44/44 [00:14<00:00,  2.98it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/TCGA_CS_4943_20000902: 100%|██████████| 40/40 [00:13<00:00,  2.94it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/TCGA_CS_5395_19981004: 100%|██████████| 40/40 [00:13<00:00,  2.99it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/TCGA_CS_4944_20010208: 100%|██████████| 40/40 [00:13<00:00,  2.93it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/TCGA_CS_6186_20000601: 100%|██████████| 50/50 [00:17<00:00,  2.88it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/TCGA_CS_5393_19990606: 100%|██████████| 40/40 [00:13<00:00,  3.01it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/TCGA_CS_6290_20000917: 100%|██████████| 40/40 [00:16<00:00,  2.41it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/TCGA_DU_5851_19950428: 100%|██████████| 80/80 [00:25<00:00,  3.13it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/TCGA_DU_5849_19950405: 100%|██████████| 76/76 [00:25<00:00,  2.94it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/TCGA_DU_5852_19950709: 100%|██████████| 72/72 [00:24<00:00,  2.95it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/TCGA
/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/TCGA_HT_7860_19960513: 100%|██████████| 44/44 [00:13<00:00,  3.37it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/TCGA_HT_7881_19981015: 100%|██████████| 160/160 [00:03<00:00, 52.63it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/TCGA_HT_8105_19980826: 100%|██████████| 64/64 [00:20<00:00,  3.07it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/TCGA_HT_8563_19981209: 100%|██████████| 46/46 [00:13<00:00,  3.37it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/TCGA_HT_8113_19930809: 100%|██████████| 42/42 [00:13<00:00,  3.16it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/TCGA_HT_A616_19991226: 100%|██████████| 56/56 [00:16<00:00,  3.33it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/TCGA_HT_8107_19980708: 100%|██████████| 40/40 [00:11<00:00,  3.34it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/TCGA_HT_A61B_19991127: 100%|██████████| 176/176 [00:03<00:00, 55.90it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/TCGA_HT_8111_19980330: 100%|██████████| 44/44 [00:12<00:00,  3.48it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/TCGA_HT_8114_19981030: 100%|██████████| 44/44 [00:13<00:00,  3.27it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/TCGA_HT_8106_19970727: 100%|██████████| 44/44 [00:13<00:00,  3.16it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/TCGA_HT_A5RC_19990831: 100%|██████████| 64/64 [00:20<00:00,  3.20it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/TCGA_HT_A61A_20000127: 100%|██████████| 176/176 [00:02<00:00, 70.10it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/segmentation: 100%|██████████| 2/2 [00:00<00:00, 33420.75it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/segmentation/.git: 100%|██████████| 6/6 [00:00<00:00, 77433.30it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/segmentation/.git/branches: 0it [00:00, ?it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/segmentation/.git/hooks: 100%|██████████| 13/13 [00:00<00:00, 254794.17it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/segmentation/.git/info: 100%|██████████| 1/1 [00:00<00:00, 19328.59it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/segmentation/.git/refs: 0it [00:00, ?it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/segmentation/.git/refs/heads: 100%|██████████| 1/1 [00:00<00:00, 13148.29it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/segmentation/.git/refs/tags: 0it [00:00, ?it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/segmentation/.git/refs/remotes: 0it [00:00, ?it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/segmentation/.git/refs/remotes/origin: 100%|██████████| 1/1 [00:00<00:00, 7384.34it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/segmentation/.git/objects: 0it [00:00, ?it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/segmentation/.git/objects/pack: 100%|██████████| 2/2 [00:00<00:00, 31895.85it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/segmentation/.git/objects/info: 0it [00:00, ?it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/segmentation/.git/objects/91: 100%|██████████| 1/1 [00:00<00:00, 8144.28it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/segmentation/.git/objects/b9: 100%|██████████| 1/1 [00:00<00:00, 13981.01it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/segmentation/.git/objects/7b: 100%|██████████| 1/1 [00:00<00:00, 16513.01it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/segmentation/.git/logs: 100%|██████████| 1/1 [00:00<00:00, 10810.06it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/segmentation/.git/logs/refs: 0it [00:00, ?it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/segmentation/.git/logs/refs/remotes: 0it [00:00, ?it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/segmentation/.git/logs/refs/remotes/origin: 100%|██████████| 1/1 [00:00<00:00, 17772.47it/s]
# Processing /content/drive/MyDrive/seg/kaggle_3m/segmentation/.git/logs/refs/heads: 100%|██████████| 1/1 [00:00<00:00, 13400.33it/s]
# ✅ Images shape (3929, 128, 128, 1)
# ✅ Masks shape (3929, 128, 128, 1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    images, masks, test_size=0.2, random_state=42
)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (3143, 128, 128, 1) (3143, 128, 128, 1)
# (786, 128, 128, 1) (786, 128, 128, 1)

# %%
im_width = 128
im_height = 128

# %%
def unet(input_size=(128, 128, 1)):

    inputs = Input(input_size)

    # First DownConvolution / Encoder Leg will begin, so start with Conv2D
    conv1 = Conv2D(filters=64, kernel_size=(3, 3), padding="same")(inputs)
    bn1 = Activation("relu")(conv1)
    conv1 = Conv2D(filters=64, kernel_size=(3, 3), padding="same")(bn1)
    bn1 = BatchNormalization(axis=3)(conv1)
    bn1 = Activation("relu")(bn1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(bn1)
    # First DownSampling
    conv2 = Conv2D(filters=128, kernel_size=(3, 3), padding="same")(pool1)
    bn2 = Activation("relu")(conv2)
    conv2 = Conv2D(filters=128, kernel_size=(3, 3), padding="same")(bn2)
    bn2 = BatchNormalization(axis=3)(conv2)
    bn2 = Activation("relu")(bn2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(bn2)
    #Second DownSampling
    conv3 = Conv2D(filters=256, kernel_size=(3, 3), padding="same")(pool2)
    bn3 = Activation("relu")(conv3)
    conv3 = Conv2D(filters=256, kernel_size=(3, 3), padding="same")(bn3)
    bn3 = BatchNormalization(axis=3)(conv3)
    bn3 = Activation("relu")(bn3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(bn3)
    # Third DownSampling
    conv4 = Conv2D(filters=512, kernel_size=(3, 3), padding="same")(pool3)
    bn4 = Activation("relu")(conv4)
    conv4 = Conv2D(filters=512, kernel_size=(3, 3), padding="same")(bn4)
    bn4 = BatchNormalization(axis=3)(conv4)
    bn4 = Activation("relu")(bn4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(bn4)

    conv5 = Conv2D(filters=1024, kernel_size=(3, 3), padding="same")(pool4)
    bn5 = Activation("relu")(conv5)
    conv5 = Conv2D(filters=1024, kernel_size=(3, 3), padding="same")(bn5)
    bn5 = BatchNormalization(axis=3)(conv5)
    bn5 = Activation("relu")(bn5)

    up6 = concatenate([Conv2DTranspose(512, kernel_size=(2, 2), strides=(2, 2), padding="same")(bn5), conv4], axis=3)
    """ After every concatenation we again apply two consecutive regular convolutions so that the model can learn to assemble a more precise output """
    conv6 = Conv2D(filters=512, kernel_size=(3, 3), padding="same")(up6)
    bn6 = Activation("relu")(conv6)
    conv6 = Conv2D(filters=512, kernel_size=(3, 3), padding="same")(bn6)
    bn6 = BatchNormalization(axis=3)(conv6)
    bn6 = Activation("relu")(bn6)

    up7 = concatenate([Conv2DTranspose(256, kernel_size=(2, 2), strides=(2, 2), padding="same")(bn6),conv3], axis=3)
    conv7 = Conv2D(filters=256, kernel_size=(3, 3), padding="same")(up7)
    bn7 = Activation("relu")(conv7)
    conv7 = Conv2D(filters=256, kernel_size=(3, 3), padding="same")(bn7)
    bn7 = BatchNormalization(axis=3)(conv7)
    bn7 = Activation("relu")(bn7)

    up8 = concatenate([Conv2DTranspose(128, kernel_size=(2, 2), strides=(2, 2), padding="same")(bn7),conv2], axis=3)
    conv8 = Conv2D(filters=128, kernel_size=(3, 3), padding="same")(up8)
    bn8 = Activation("relu")(conv8)
    conv8 = Conv2D(filters=128, kernel_size=(3, 3), padding="same")(bn8)
    bn8 = BatchNormalization(axis=3)(conv8)
    bn8 = Activation("relu")(bn8)

    up9 = concatenate([Conv2DTranspose(64, kernel_size=(2, 2), strides=(2, 2), padding="same")(bn8),conv1],axis=3)
    conv9 = Conv2D(filters=64, kernel_size=(3, 3), padding="same")(up9)
    bn9 = Activation("relu")(conv9)
    conv9 = Conv2D(filters=64, kernel_size=(3, 3), padding="same")(bn9)
    bn9 = BatchNormalization(axis=3)(conv9)
    bn9 = Activation("relu")(bn9)

    conv10 = Conv2D(filters=1, kernel_size=(1, 1), activation="sigmoid")(bn9)

    return Model(inputs=[inputs], outputs=[conv10])

# %%
model = unet()
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │        640 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 128, 128,  │          0 │ conv2d[0][0]      │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │     36,928 │ activation[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 128, 128,  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 64,    │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 64,    │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 64, 64,    │          0 │ conv2d_2[0][0]    │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 64, 64,    │    147,584 │ activation_2[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 32,    │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 32, 32,    │          0 │ conv2d_4[0][0]    │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │    590,080 │ activation_4[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 16, 16,    │          0 │ activation_5[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 16, 16,    │  1,180,160 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 16, 16,    │          0 │ conv2d_6[0][0]    │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │  2,359,808 │ activation_6[0][… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 8, 8, 512) │          0 │ activation_7[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 8, 8,      │  4,719,616 │ max_pooling2d_3[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 8, 8,      │          0 │ conv2d_8[0][0]    │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 8, 8,      │  9,438,208 │ activation_8[0][… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8,      │      4,096 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 8, 8,      │          0 │ batch_normalizat… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 16, 16,    │  2,097,664 │ activation_9[0][… │
# │ (Conv2DTranspose)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1024)             │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 16, 16,    │  4,719,104 │ concatenate[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 16, 16,    │          0 │ conv2d_10[0][0]   │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 16, 16,    │  2,359,808 │ activation_10[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 32, 32,    │    524,544 │ activation_11[0]… │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 32, 32,    │  1,179,904 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 32, 32,    │          0 │ conv2d_12[0][0]   │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 32, 32,    │    590,080 │ activation_12[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 64, 64,    │    131,200 │ activation_13[0]… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 64, 64,    │    295,040 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 64, 64,    │          0 │ conv2d_14[0][0]   │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 64, 64,    │    147,584 │ activation_14[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 128, 128,  │     32,832 │ activation_15[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 128, 128,  │     73,792 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 128, 128,  │          0 │ conv2d_16[0][0]   │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 128, 128,  │     36,928 │ activation_16[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 128, 128,  │         65 │ activation_17[0]… │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,042,369 (118.42 MB)
#  Trainable params: 31,036,481 (118.39 MB)
#  Non-trainable params: 5,888 (23.00 KB)

# %%
def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

# %%
from tensorflow.keras.optimizers import Adam

model.compile(optimizer=Adam(learning_rate=1e-4), loss=dice_loss, metrics=[dice_coef])

# %%
checkpoint = ModelCheckpoint("unet_model.h5", save_best_only=True, monitor='val_loss', mode='min')
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    batch_size=16,
    epochs=50,
    callbacks=[checkpoint, early_stop]
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(None, 128, 128, 1))
#   warnings.warn(msg)
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - dice_coef: 0.0904 - loss: 0.9096
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 123s 440ms/step - dice_coef: 0.0906 - loss: 0.9094 - val_dice_coef: 0.0177 - val_loss: 0.9820
# Epoch 2/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - dice_coef: 0.2089 - loss: 0.7911
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 59s 301ms/step - dice_coef: 0.2090 - loss: 0.7910 - val_dice_coef: 0.0213 - val_loss: 0.9784
# Epoch 3/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - dice_coef: 0.3160 - loss: 0.6840
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 84s 310ms/step - dice_coef: 0.3162 - loss: 0.6838 - val_dice_coef: 0.3738 - val_loss: 0.6197
# Epoch 4/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - dice_coef: 0.4655 - loss: 0.5345
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 83s 316ms/step - dice_coef: 0.4656 - loss: 0.5344 - val_dice_coef: 0.4955 - val_loss: 0.4958
# Epoch 5/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 71s 263ms/step - dice_coef: 0.5636 - loss: 0.4364 - val_dice_coef: 0.1966 - val_loss: 0.8001
# Epoch 6/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - dice_coef: 0.5982 - loss: 0.4018
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 90s 304ms/step - dice_coef: 0.5983 - loss: 0.4017 - val_dice_coef: 0.6582 - val_loss: 0.3304
# Epoch 7/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 74s 263ms/step - dice_coef: 0.6642 - loss: 0.3358 - val_dice_coef: 0.5753 - val_loss: 0.4147
# Epoch 8/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 81s 257ms/step - dice_coef: 0.6651 - loss: 0.3349 - val_dice_coef: 0.6353 - val_loss: 0.3538
# Epoch 9/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - dice_coef: 0.7418 - loss: 0.2582
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 90s 297ms/step - dice_coef: 0.7417 - loss: 0.2582 - val_dice_coef: 0.6861 - val_loss: 0.3021
# Epoch 10/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - dice_coef: 0.7544 - loss: 0.2456
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 57s 292ms/step - dice_coef: 0.7545 - loss: 0.2455 - val_dice_coef: 0.7334 - val_loss: 0.2540
# Epoch 11/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 76s 263ms/step - dice_coef: 0.7904 - loss: 0.2096 - val_dice_coef: 0.6962 - val_loss: 0.2918
# Epoch 12/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - dice_coef: 0.7830 - loss: 0.2170
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 93s 319ms/step - dice_coef: 0.7829 - loss: 0.2170 - val_dice_coef: 0.7579 - val_loss: 0.2291
# Epoch 13/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 71s 262ms/step - dice_coef: 0.8024 - loss: 0.1976 - val_dice_coef: 0.6344 - val_loss: 0.3548
# Epoch 14/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 81s 257ms/step - dice_coef: 0.7376 - loss: 0.2624 - val_dice_coef: 0.7182 - val_loss: 0.2696
# Epoch 15/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - dice_coef: 0.8191 - loss: 0.1809
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 95s 323ms/step - dice_coef: 0.8190 - loss: 0.1810 - val_dice_coef: 0.7746 - val_loss: 0.2121
# Epoch 16/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - dice_coef: 0.8238 - loss: 0.1762
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 88s 355ms/step - dice_coef: 0.8238 - loss: 0.1762 - val_dice_coef: 0.7919 - val_loss: 0.1946
# Epoch 17/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 63s 257ms/step - dice_coef: 0.8194 - loss: 0.1806 - val_dice_coef: 0.7486 - val_loss: 0.2386
# Epoch 18/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 83s 262ms/step - dice_coef: 0.7970 - loss: 0.2030 - val_dice_coef: 0.7564 - val_loss: 0.2307
# Epoch 19/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 81s 256ms/step - dice_coef: 0.8371 - loss: 0.1629 - val_dice_coef: 0.6601 - val_loss: 0.3283
# Epoch 20/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - dice_coef: 0.8010 - loss: 0.1990
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 94s 317ms/step - dice_coef: 0.8011 - loss: 0.1989 - val_dice_coef: 0.7928 - val_loss: 0.1937
# Epoch 21/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - dice_coef: 0.8365 - loss: 0.1635
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 83s 322ms/step - dice_coef: 0.8365 - loss: 0.1635 - val_dice_coef: 0.7960 - val_loss: 0.1905
# Epoch 22/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - dice_coef: 0.8482 - loss: 0.1518
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 82s 322ms/step - dice_coef: 0.8482 - loss: 0.1518 - val_dice_coef: 0.7966 - val_loss: 0.1899
# Epoch 23/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - dice_coef: 0.8568 - loss: 0.1432
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 78s 302ms/step - dice_coef: 0.8567 - loss: 0.1433 - val_dice_coef: 0.7996 - val_loss: 0.1868
# Epoch 24/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 73s 257ms/step - dice_coef: 0.8417 - loss: 0.1583 - val_dice_coef: 0.6790 - val_loss: 0.3093
# Epoch 25/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 82s 256ms/step - dice_coef: 0.8400 - loss: 0.1600 - val_dice_coef: 0.7116 - val_loss: 0.2763
# Epoch 26/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - dice_coef: 0.8542 - loss: 0.1458
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 60s 304ms/step - dice_coef: 0.8542 - loss: 0.1458 - val_dice_coef: 0.8072 - val_loss: 0.1791
# Epoch 27/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 74s 263ms/step - dice_coef: 0.8527 - loss: 0.1473 - val_dice_coef: 0.5993 - val_loss: 0.3907
# Epoch 28/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 80s 256ms/step - dice_coef: 0.8269 - loss: 0.1731 - val_dice_coef: 0.7914 - val_loss: 0.1951
# Epoch 29/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 82s 256ms/step - dice_coef: 0.8482 - loss: 0.1518 - val_dice_coef: 0.7794 - val_loss: 0.2074
# Epoch 30/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 83s 261ms/step - dice_coef: 0.8522 - loss: 0.1478 - val_dice_coef: 0.8048 - val_loss: 0.1815
# Epoch 31/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - dice_coef: 0.8656 - loss: 0.1344
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 94s 322ms/step - dice_coef: 0.8656 - loss: 0.1344 - val_dice_coef: 0.8203 - val_loss: 0.1657
# Epoch 32/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 69s 256ms/step - dice_coef: 0.8596 - loss: 0.1404 - val_dice_coef: 0.8130 - val_loss: 0.1732
# Epoch 33/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 83s 262ms/step - dice_coef: 0.8803 - loss: 0.1197 - val_dice_coef: 0.7711 - val_loss: 0.2159
# Epoch 34/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 49s 250ms/step - dice_coef: 0.8342 - loss: 0.1658 - val_dice_coef: 0.3190 - val_loss: 0.6760
# Epoch 35/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 51s 258ms/step - dice_coef: 0.7235 - loss: 0.2765 - val_dice_coef: 0.7366 - val_loss: 0.2509
# Epoch 36/50
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 51s 257ms/step - dice_coef: 0.8224 - loss: 0.1776 - val_dice_coef: 0.6660 - val_loss: 0.3228

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title("Training & Validation Loss")
plt.show()

plt.plot(history.history['dice_coef'], label='Training Dice')
plt.plot(history.history['val_dice_coef'], label='Validation Dice')
plt.legend()
plt.title("Training & Validation Dice Coefficient")
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 30s 640ms/step - dice_coef: 0.8443 - loss: 0.1557
# [0.14498992264270782, 0.8548916578292847]

# %%
i = random.randint(0, len(X_test)-1)
test_img = X_test[i]
test_mask = y_test[i]
pred_mask = model.predict(np.expand_dims(test_img, axis=0))[0]

plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.title("Input Image")
plt.imshow(test_img.squeeze(), cmap='gray')

plt.subplot(1, 3, 2)
plt.title("True Mask")
plt.imshow(test_mask.squeeze(), cmap='gray')

plt.subplot(1, 3, 3)
plt.title("Predicted Mask")
plt.imshow(pred_mask.squeeze(), cmap='gray')

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step

# %%
model.save('unet_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
